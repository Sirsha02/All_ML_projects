# %% [markdown]
# # 1. Importing Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# # 2. Importing the Dataset

# %%
data = pd.read_csv("news.csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %% [markdown]
# # 3. Preprocessing Dataset

# %%
data = data.drop(["Unnamed: 0"], axis=1)
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %% [markdown]
# # 4. Data Encoding

# %%
le = preprocessing.LabelEncoder()
le.fit(data['label'])
data['label'] = le.transform(data['label'])

# %% [markdown]
# # 5. Variables Setup

# %%
embedding_dim = 50
max_length = 54
padding_type = 'post'
trunc_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = 0.1

# %% [markdown]
# # 6. Tokenization

# %%
title = []
text = []
labels = []
for x in range(training_size):
    title.append(data['title'][x])
    text.append(data['text'][x])
    labels.append(data['label'][x])

tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(title)
word_index1 = tokenizer1.word_index
vocab_size1 = len(word_index1)
sequences1 = tokenizer1.texts_to_sequences(title)
padded1 = pad_sequences(sequences1, padding=padding_type, truncating=trunc_type)

# %% [markdown]
# # 7. Splitting Data for Training and Testing

# %%
split = int(test_portion * training_size)
training_sequences1 = padded1[split:training_size]
test_sequences1 = padded1[0:split]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %% [markdown]
# # 8. Reshaping Data for LSTM

# %%
training_sequences1 = np.array(training_sequences1)
test_sequences1 = np.array(test_sequences1)

# %% [markdown]
# # 9. Generating Word Embedding

# %%
import urllib.request
import zipfile

# Download the file
url = "https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip"
urllib.request.urlretrieve(url, "glove.6B.zip")

# Unzip the file
with zipfile.ZipFile("glove.6B.zip", "r") as zip_ref:
    zip_ref.extractall(".")

# %%
embedding_index = {}
with open('glove.6B.50d.txt', 'r', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embedding_index[word] = coefs
        
embedding_matrix = np.zeros((vocab_size1 + 1, embedding_dim))

for word, i in word_index1.items():
    if i < vocab_size1:
        embedding_vector = embedding_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector

# %% [markdown]
# # 10. Model Architecture

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size1 + 1, embedding_dim, input_length=max_length, 
                              weights=[embedding_matrix], trainable=False),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │       377,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 377,600 (1.44 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 377,600 (1.44 MB)

# %% [markdown]
# # 11. Training the Model

# %%
history = model.fit(
    training_sequences1, 
    np.array(training_labels), 
    epochs=50, 
    validation_data=(test_sequences1, np.array(test_labels)), 
    verbose=2
)
# Out:
# Epoch 1/50
# 85/85 - 9s - 101ms/step - accuracy: 0.6137 - loss: 0.6484 - val_accuracy: 0.6467 - val_loss: 0.5967
# Epoch 2/50
# 85/85 - 1s - 13ms/step - accuracy: 0.7074 - loss: 0.5737 - val_accuracy: 0.6900 - val_loss: 0.5453
# Epoch 3/50
# 85/85 - 1s - 12ms/step - accuracy: 0.7244 - loss: 0.5355 - val_accuracy: 0.7167 - val_loss: 0.5355
# Epoch 4/50
# 85/85 - 1s - 12ms/step - accuracy: 0.7611 - loss: 0.4898 - val_accuracy: 0.7467 - val_loss: 0.4934
# Epoch 5/50
# 85/85 - 1s - 12ms/step - accuracy: 0.7804 - loss: 0.4554 - val_accuracy: 0.7300 - val_loss: 0.5163
# Epoch 6/50
# 85/85 - 1s - 12ms/step - accuracy: 0.8207 - loss: 0.4034 - val_accuracy: 0.7233 - val_loss: 0.5516
# Epoch 7/50
# 85/85 - 1s - 14ms/step - accuracy: 0.8367 - loss: 0.3604 - val_accuracy: 0.7100 - val_loss: 0.5535
# Epoch 8/50
# 85/85 - 1s - 15ms/step - accuracy: 0.8756 - loss: 0.3021 - val_accuracy: 0.7000 - val_loss: 0.6886
# Epoch 9/50
# 85/85 - 1s - 14ms/step - accuracy: 0.8700 - loss: 0.3111 - val_accuracy: 0.7167 - val_loss: 0.5598
# Epoch 10/50
# 85/85 - 1s - 17ms/step - accuracy: 0.8878 - loss: 0.2710 - val_accuracy: 0.7467 - val_loss: 0.6299
# Epoch 11/50
# 85/85 - 2s - 21ms/step - accuracy: 0.8937 - loss: 0.2527 - val_accuracy: 0.7433 - val_loss: 0.5575
# Epoch 12/50
# 85/85 - 1s - 15ms/step - accuracy: 0.9159 - loss: 0.2109 - val_accuracy: 0.7467 - val_loss: 0.6331
# Epoch 13/50
# 85/85 - 1s - 16ms/step - accuracy: 0.9141 - loss: 0.2146 - val_accuracy: 0.7333 - val_loss: 0.6518
# Epoch 14/50
# 85/85 - 1s - 15ms/step - accuracy: 0.9178 - loss: 0.1917 - val_accuracy: 0.7567 - val_loss: 0.6087
# Epoch 15/50
# 85/85 - 1s - 15ms/step - accuracy: 0.9300 - loss: 0.1856 - val_accuracy: 0.7267 - val_loss: 0.6395
# Epoch 16/50
# 85/85 - 1s - 16ms/step - accuracy: 0.9296 - loss: 0.1779 - val_accuracy: 0.7667 - val_loss: 0.6473
# Epoch 17/50
# 85/85 - 1s - 16ms/step - accuracy: 0.9337 - loss: 0.1667 - val_accuracy: 0.7000 - val_loss: 0.8214
# Epoch 18/50
# 85/85 - 1s - 14ms/step - accuracy: 0.9330 - loss: 0.1722 - val_accuracy: 0.7700 - val_loss: 0.6641
# Epoch 19/50
# 85/85 - 1s - 14ms/step - accuracy: 0.9474 - loss: 0.1434 - val_accuracy: 0.7567 - val_loss: 0.6858
# Epoch 20/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9526 - loss: 0.1206 - val_accuracy: 0.7267 - val_loss: 0.7491
# Epoch 21/50
# 85/85 - 1s - 17ms/step - accuracy: 0.9489 - loss: 0.1294 - val_accuracy: 0.7467 - val_loss: 0.8723
# Epoch 22/50
# 85/85 - 1s - 15ms/step - accuracy: 0.9570 - loss: 0.1191 - val_accuracy: 0.7567 - val_loss: 0.7424
# Epoch 23/50
# 85/85 - 1s - 16ms/step - accuracy: 0.9570 - loss: 0.1170 - val_accuracy: 0.7400 - val_loss: 0.8356
# Epoch 24/50
# 85/85 - 2s - 22ms/step - accuracy: 0.9578 - loss: 0.1163 - val_accuracy: 0.7333 - val_loss: 0.8838
# Epoch 25/50
# 85/85 - 1s - 14ms/step - accuracy: 0.9567 - loss: 0.1121 - val_accuracy: 0.7433 - val_loss: 0.8719
# Epoch 26/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9644 - loss: 0.0877 - val_accuracy: 0.7333 - val_loss: 0.9743
# Epoch 27/50
# 85/85 - 1s - 10ms/step - accuracy: 0.9548 - loss: 0.1166 - val_accuracy: 0.7267 - val_loss: 0.7710
# Epoch 28/50
# 85/85 - 1s - 10ms/step - accuracy: 0.9515 - loss: 0.1255 - val_accuracy: 0.7567 - val_loss: 0.8165
# Epoch 29/50
# 85/85 - 1s - 9ms/step - accuracy: 0.9674 - loss: 0.0848 - val_accuracy: 0.7233 - val_loss: 0.9518
# Epoch 30/50
# 85/85 - 1s - 9ms/step - accuracy: 0.9737 - loss: 0.0764 - val_accuracy: 0.7267 - val_loss: 1.0562
# Epoch 31/50
# 85/85 - 1s - 9ms/step - accuracy: 0.9522 - loss: 0.1222 - val_accuracy: 0.7400 - val_loss: 0.8256
# Epoch 32/50
# 85/85 - 1s - 8ms/step - accuracy: 0.9733 - loss: 0.0830 - val_accuracy: 0.7333 - val_loss: 0.9399
# Epoch 33/50
# 85/85 - 1s - 9ms/step - accuracy: 0.9722 - loss: 0.0842 - val_accuracy: 0.7300 - val_loss: 0.9172
# Epoch 34/50
# 85/85 - 1s - 9ms/step - accuracy: 0.9730 - loss: 0.0749 - val_accuracy: 0.7400 - val_loss: 0.9271
# Epoch 35/50
# 85/85 - 1s - 9ms/step - accuracy: 0.9707 - loss: 0.0730 - val_accuracy: 0.7500 - val_loss: 1.1528
# Epoch 36/50
# 85/85 - 1s - 10ms/step - accuracy: 0.9722 - loss: 0.0853 - val_accuracy: 0.7200 - val_loss: 0.9327
# Epoch 37/50
# 85/85 - 1s - 9ms/step - accuracy: 0.9778 - loss: 0.0651 - val_accuracy: 0.7433 - val_loss: 1.0704
# Epoch 38/50
# 85/85 - 1s - 10ms/step - accuracy: 0.9715 - loss: 0.0703 - val_accuracy: 0.7400 - val_loss: 1.0365
# Epoch 39/50
# 85/85 - 1s - 9ms/step - accuracy: 0.9678 - loss: 0.0867 - val_accuracy: 0.7533 - val_loss: 0.7520
# Epoch 40/50
# 85/85 - 1s - 9ms/step - accuracy: 0.9726 - loss: 0.0688 - val_accuracy: 0.7367 - val_loss: 0.9471
# Epoch 41/50
# 85/85 - 1s - 10ms/step - accuracy: 0.9726 - loss: 0.0695 - val_accuracy: 0.7300 - val_loss: 1.0155
# Epoch 42/50
# 85/85 - 1s - 10ms/step - accuracy: 0.9752 - loss: 0.0720 - val_accuracy: 0.7400 - val_loss: 1.0595
# Epoch 43/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9696 - loss: 0.0740 - val_accuracy: 0.7500 - val_loss: 1.0779
# Epoch 44/50
# 85/85 - 1s - 10ms/step - accuracy: 0.9770 - loss: 0.0682 - val_accuracy: 0.7367 - val_loss: 0.9254
# Epoch 45/50
# 85/85 - 1s - 10ms/step - accuracy: 0.9711 - loss: 0.0692 - val_accuracy: 0.7333 - val_loss: 1.0501
# Epoch 46/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9711 - loss: 0.0813 - val_accuracy: 0.7033 - val_loss: 0.8573
# Epoch 47/50
# 85/85 - 1s - 10ms/step - accuracy: 0.9789 - loss: 0.0532 - val_accuracy: 0.7233 - val_loss: 1.1977
# Epoch 48/50
# 85/85 - 1s - 10ms/step - accuracy: 0.9759 - loss: 0.0728 - val_accuracy: 0.7267 - val_loss: 1.0161
# Epoch 49/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9789 - loss: 0.0607 - val_accuracy: 0.7167 - val_loss: 1.0535
# Epoch 50/50
# 85/85 - 1s - 8ms/step - accuracy: 0.9752 - loss: 0.0669 - val_accuracy: 0.7067 - val_loss: 0.9449

# %% [markdown]
# # 12. Sample Prediction

# %%
X = "Karry to go to France in gesture of sympathy"

sequences = tokenizer1.texts_to_sequences([X])
sequences = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
if model.predict(sequences, verbose=0)[0][0] >= 0.5:
    print("This news is True")
else:
    print("This news is False")
# Out:
# This news is False
